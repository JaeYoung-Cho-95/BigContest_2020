# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import os
# %matplotlib inline

# %% [markdown]
# 폰트 지정(내장 기본폰트를 활용하지 않고 독자적인 폰트이기때문에 fm.findSystemFonts() 를 활용하여 각 PC의 폰트의 절대경로를 찾아 사용하기 바랍니다)

# %%
path = "C:\\Users\\EPM_sales\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothic.ttf"
font_name = fm.FontProperties(fname=path,size=18).get_name()
print(font_name)
plt.rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %% [markdown]
# 가용 데이터를 전체 파일로드 자동화

# %%
data_path = os.path.abspath("../Data/Data")

# %%
#각 데이터 파일에 맞춰서 구분자를 함수화 해줌
def sep(name):
    if name == 'SNS':
        return ''
    elif name == 'Card':
        return '\t'
    elif name == 'Logistics':
        return ' '
    elif name == 'People':
        return '|'
    elif name == 'Delivery':
        return ' '
    elif name == 'Corona':
        return ','

# %%
""" dict 타입의 Data 변수 안에 각 데이터들이 구조화 되어 저장 
    각 데이터 들이 들어갈때마다 키값 밑으로 파일들이 well-unpacking됨을 알리도록 print
    각 Item들은 list로 구성되어 unpacking된 dataset들이 들어감
    file unpacking이 끝나면 파일이름과 순서가 sort되어있는 metadata를 EOL에 append
"""
Data = {}
for path in os.listdir(data_path):
    datas  = os.listdir(data_path+"\\"+path)
    data_ex = []
    print(path,":")
    if path not in Data:
        Data[path] = []
    for data in datas:
        data_ex.append(data)
        print(data_path+path+"\\"+data)

        if data[-4:] == 'xlsx':
            cnt = 0
            temp = pd.ExcelFile(data_path+"\\"+path+"\\"+data)
            for st_name in temp.sheet_names:
                Data[path].append(pd.read_excel(temp,st_name))
                cnt+=1
            data_ex.append(data_ex.pop()+"_stcount_"+str(cnt))
        else:
            try:
                Data[path].append(pd.read_csv(data_path+"\\"+path+"\\"+data,encoding='cp949',engine='python',sep=sep(path)))
            except Exception as e:
                Data[path].append(pd.read_csv(data_path+"\\"+path+"\\"+data,encoding='utf-8-sig',engine='python',sep=sep(path)))
    Data[path].append(data_ex)
# Out:
# Card :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataCard\02_혁신아이디어분야_카드소비데이터(신한카드)_데이터정의서.xlsx
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataCard\CARD_SPENDING_FOREIGNER.txt
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataCard\CARD_SPENDING_RESIDENT.txt
# Corona :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataCorona\코로나 일별.csv
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataCorona\코로나 지역별.csv
# Delivery :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataDelivery\04_혁신아이디어분야_유통데이터(GS리테일)_데이터정의서 및 문제 데이터.xlsx
# Logistics :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataLogistics\05_혁신아이디어분야_물류데이터(CJ올리브네트웍스)_데이터정의서.xlsx
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataLogistics\2020 빅콘테스트_CJ올리브네트웍스_제공DB.xlsx
# People :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\01_혁신아이디어분야_유동인구데이터(SK텔레콤)_데이터정의서.xlsx
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_201902.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_201903.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_201904.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_201905.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_202002.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_202003.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_202004.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_AGE_202005.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_201902.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_201903.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_201904.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_201905.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_202002.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_202003.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_202004.CSV
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataPeople\4개지역_FLOW_TIME_202005.CSV
# SNS :
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataSNS\03_혁신아이디어분야_SNS데이터(와이즈넛)_데이터정의서.xlsx
# C:\Users\EPM_sales\Desktop\Kimdongui\ML_with_PY\Bigcontest2020\Data\DataSNS\2020 bigcontest data_wisenut.csv

# %%
#다음은 각 file의 unpacking된 현황과 메타 데이터이다
#인덱스가 필요할때는 enumerate를 활용하거나 zip을 통해서 이름으로 hashing도 가능
#엑셀 파일의 경우 엑셀의 총 시트수를 메타데이터에 표시하여 총 몇시트를 불러왔는지 알 수 있게함
#물류 데이터의 경우 첫 시트만 데이터가 존재하고 나머지 두시트는 공시트였음
for i in Data:
    print(i,":")
    for j in Data[i][-1]:
        print(" ",j)
# Out:
# Card :
#   02_혁신아이디어분야_카드소비데이터(신한카드)_데이터정의서.xlsx_stcount_4
#   CARD_SPENDING_FOREIGNER.txt
#   CARD_SPENDING_RESIDENT.txt
# Corona :
#   코로나 일별.csv
#   코로나 지역별.csv
# Delivery :
#   04_혁신아이디어분야_유통데이터(GS리테일)_데이터정의서 및 문제 데이터.xlsx_stcount_6
# Logistics :
#   05_혁신아이디어분야_물류데이터(CJ올리브네트웍스)_데이터정의서.xlsx_stcount_2
#   2020 빅콘테스트_CJ올리브네트웍스_제공DB.xlsx_stcount_3
# People :
#   01_혁신아이디어분야_유동인구데이터(SK텔레콤)_데이터정의서.xlsx_stcount_1
#   4개지역_FLOW_AGE_201902.CSV
#   4개지역_FLOW_AGE_201903.CSV
#   4개지역_FLOW_AGE_201904.CSV
#   4개지역_FLOW_AGE_201905.CSV
#   4개지역_FLOW_AGE_202002.CSV
#   4개지역_FLOW_AGE_202003.CSV
#   4개지역_FLOW_AGE_202004.CSV
#   4개지역_FLOW_AGE_202005.CSV
#   4개지역_FLOW_TIME_201902.CSV
#   4개지역_FLOW_TIME_201903.CSV
#   4개지역_FLOW_TIME_201904.CSV
#   4개지역_FLOW_TIME_201905.CSV
#   4개지역_FLOW_TIME_202002.CSV
#   4개지역_FLOW_TIME_202003.CSV
#   4개지역_FLOW_TIME_202004.CSV
#   4개지역_FLOW_TIME_202005.CSV
# SNS :
#   03_혁신아이디어분야_SNS데이터(와이즈넛)_데이터정의서.xlsx_stcount_4
#   2020 bigcontest data_wisenut.csv

# %% [markdown]
# # 데이터 전처리 PART

# %% [markdown]
# 포함데이터:
# - 물류 데이터
# - 유동인구 데이터
# - 카드매출 데이터
# - 유통 데이터

# %% [markdown]
# 외부데이터:
# - 코로나 데이터

# %% [markdown]
# # 물류 데이터 핸들링

# %%
Data['Logistics'][0]
# Out:
#     Unnamed: 0 Unnamed: 1     Unnamed: 2  \
# 0          NaN    테이블 정의서            NaN
# 1          NaN       테이블명            NaN
# 2          NaN      테이블개요            NaN
# 3          NaN       특기사항            NaN
# 4          NaN         순서           컬럼ID
# 5          NaN          1         DL_YMD
# 6          NaN          2  DL_GD_LCLS_NM
# 7          NaN          3  DL_GD_LCLS_CD
# 8          NaN          4        CTPV_NM
# 9          NaN          5        CTPV_CD
# 10         NaN          6        CTGG_NM
# 11         NaN          7        CTGG_CD
# 12         NaN          8        HDNG_NM
# 13         NaN          9        HDNG_CD
# 14         NaN         10      INVC_CONT
#
#                                            Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN
# 1                                일자별 행정동별 카테고리별 물류 건수        NaN
# 2               [적재주기 : 일단위] \n기준지역 내 일자별 카테고리별 물류 건수        NaN
# 3   1. 기간 : '19년 2월 1일~'19년 5월 31일, '20년 2월 1일~'20...        NaN
# 4                                                 NaN        컬럼명
# 5                                                 NaN      배송년월일
# 6                                                 NaN   배송상품대분류명
# 7                                                 NaN  배송상품대분류코드
# 8                                                 NaN        시도명
# 9                                                 NaN       시도코드
# 10                                                NaN       시군구명
# 11                                                NaN      시군구코드
# 12                                                NaN       행정동명
# 13                                                NaN      행정동코드
# 14                                                NaN       송장건수
#
#       Unnamed: 5 Unnamed: 6
# 0            NaN        NaN
# 1          테이블ID  CJO00002D
# 2            NaN        NaN
# 3            NaN        NaN
# 4        물리데이터타입         비고
# 5     VARCHAR(6)        NaN
# 6   VARCHAR(100)        NaN
# 7    VARCHAR(40)        NaN
# 8    VARCHAR(50)        NaN
# 9     VARCHAR(2)        NaN
# 10   VARCHAR(50)        NaN
# 11    VARCHAR(5)        NaN
# 12   VARCHAR(50)        NaN
# 13   VARCHAR(10)        NaN
# 14    NUMBER(18)        NaN

# %%
Data['Logistics'][2]
# Out:
#         DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM  CTPV_CD CTGG_NM  CTGG_CD  \
# 0       190201         도서/음반             12   서울특별시       11      중구       14
# 1       190201       가구/인테리어             10   서울특별시       11      중구       14
# 2       190201       가구/인테리어             10   대구광역시       27      중구       11
# 3       190201         도서/음반             12   대구광역시       27      중구       11
# 4       190201        디지털/가전             13   대구광역시       27     수성구       26
# ...        ...           ...            ...     ...      ...     ...      ...
# 156566  200531          패션의류             19   대구광역시       27     수성구       26
# 156567  200531          패션의류             19   서울특별시       11      중구       14
# 156568  200531          패션잡화             20   대구광역시       27     수성구       26
# 156569  200531          패션잡화             20   서울특별시       11     노원구       35
# 156570  200531        화장품/미용             21   대구광역시       27     수성구       26
#
#        HDNG_NM  HDNG_CD  INVC_CONT
# 0          동화동      665         16
# 1          신당동      615          4
# 2         성내1동      565          1
# 3         남산2동      650          6
# 4         고산3동      690         21
# ...        ...      ...        ...
# 156566    범물2동      662         22
# 156567     약수동      635         21
# 156568    범물2동      662         14
# 156569  상계6.7동      695         25
# 156570   수성4가동      590         27
#
# [156571 rows x 10 columns]

# %%
Logi = Data['Logistics'][2]

# %%
metaLogi = dict(zip(Logi[['DL_GD_LCLS_NM','DL_GD_LCLS_CD']].drop_duplicates()['DL_GD_LCLS_CD'],Logi[['DL_GD_LCLS_NM','DL_GD_LCLS_CD']].drop_duplicates()['DL_GD_LCLS_NM']))

# %%
metaLogi
# Out:
# {12: '도서/음반',
#  10: '가구/인테리어',
#  13: '디지털/가전',
#  16: '스포츠/레저',
#  20: '패션잡화',
#  17: '식품',
#  15: '생활건강',
#  19: '패션의류',
#  21: '화장품/미용',
#  18: '출산/육아'}

# %%
Logi20 = Logi.loc[Logi['DL_YMD'] > 200000].reset_index(drop=True)
Logi19 = Logi.loc[Logi['DL_YMD'] < 200000].reset_index(drop=True)

# %%
Logi20['DL_YM'] = Logi20['DL_YMD']%10000
Logi19['DL_YM'] = Logi19['DL_YMD']%10000

# %%
key = [x for x in Logi20.drop(columns='INVC_CONT').columns[1:] if not x[-2:]=='NM']
drop = [x for x in Logi20.drop(columns='INVC_CONT').columns[1:] if x[-2:]=='NM']
delta_logi = pd.merge(Logi19.drop(columns=drop+['DL_YMD']),Logi20.drop(columns=drop+['DL_YMD']),on=key)

# %%
delta_logi
# Out:
#        DL_GD_LCLS_CD  CTPV_CD  CTGG_CD  HDNG_CD  INVC_CONT_x  DL_YM  \
# 0                 12       11       14      665           16    201
# 1                 10       11       14      615            4    201
# 2                 10       27       11      565            1    201
# 3                 12       27       11      650            6    201
# 4                 13       27       26      690           21    201
# ...              ...      ...      ...      ...          ...    ...
# 73817             20       11       14      645           55    531
# 73818             21       27       26      520          120    531
# 73819             21       11       14      625           74    531
# 73820             19       27       11      595          150    531
# 73821             20       11       14      650           55    531
#
#        INVC_CONT_y
# 0                9
# 1                4
# 2                3
# 3               11
# 4               30
# ...            ...
# 73817            9
# 73818           32
# 73819           15
# 73820           12
# 73821            6
#
# [73822 rows x 7 columns]

# %%
delta_logi['DELTA_LOGI'] = delta_logi['INVC_CONT_y'] - delta_logi['INVC_CONT_x']

# %%
delta_logi['DELTA_LOGI'].plot()
# Out:
# <AxesSubplot:>

# %%
delta_logi
# Out:
#        DL_GD_LCLS_CD  CTPV_CD  CTGG_CD  HDNG_CD  INVC_CONT_x  DL_YM  \
# 0                 12       11       14      665           16    201
# 1                 10       11       14      615            4    201
# 2                 10       27       11      565            1    201
# 3                 12       27       11      650            6    201
# 4                 13       27       26      690           21    201
# ...              ...      ...      ...      ...          ...    ...
# 73817             20       11       14      645           55    531
# 73818             21       27       26      520          120    531
# 73819             21       11       14      625           74    531
# 73820             19       27       11      595          150    531
# 73821             20       11       14      650           55    531
#
#        INVC_CONT_y  DELTA_LOGI
# 0                9          -7
# 1                4           0
# 2                3           2
# 3               11           5
# 4               30           9
# ...            ...         ...
# 73817            9         -46
# 73818           32         -88
# 73819           15         -59
# 73820           12        -138
# 73821            6         -49
#
# [73822 rows x 8 columns]

# %%
delta_logi['DL_D'] =delta_logi['DL_YM']%100

# %%
delta_logi
# Out:
#        DL_GD_LCLS_CD  CTPV_CD  CTGG_CD  HDNG_CD  INVC_CONT_x  DL_YM  \
# 0                 12       11       14      665           16    201
# 1                 10       11       14      615            4    201
# 2                 10       27       11      565            1    201
# 3                 12       27       11      650            6    201
# 4                 13       27       26      690           21    201
# ...              ...      ...      ...      ...          ...    ...
# 73817             20       11       14      645           55    531
# 73818             21       27       26      520          120    531
# 73819             21       11       14      625           74    531
# 73820             19       27       11      595          150    531
# 73821             20       11       14      650           55    531
#
#        INVC_CONT_y  DELTA_LOGI  DL_D
# 0                9          -7     1
# 1                4           0     1
# 2                3           2     1
# 3               11           5     1
# 4               30           9     1
# ...            ...         ...   ...
# 73817            9         -46    31
# 73818           32         -88    31
# 73819           15         -59    31
# 73820           12        -138    31
# 73821            6         -49    31
#
# [73822 rows x 9 columns]

# %%
def logi_things_plot(graph, code,ax):
    graph = graph[:]
    graph = graph.loc[graph['DL_GD_LCLS_CD'] == code].groupby("DL_D").sum().sort_values(by='DELTA_LOGI')
#     graph['DL_D'] = graph.index%100
#     graph = graph.set_index('DL_D')
#     graph = graph.sort_index()
    graph.loc[graph['DELTA_LOGI']<0]['DELTA_LOGI'].plot(kind='bar',ax=ax,title=metaLogi[code])

# %%
fig = plt.figure(figsize=(40,40))
cnt=1
for code in Logi['DL_GD_LCLS_CD'].unique():
    ax = fig.add_subplot(5,2,cnt)
    logi_things_plot(delta_logi,code,ax)
    cnt+=1

# %%
def logi_things_plot(graph, code,ax):
    graph = graph.loc[graph['DL_GD_LCLS_CD'] == code].groupby("DL_YM").sum().sort_values(by='DELTA_LOGI')
#     graph['DL_D'] = graph.index%100
#     graph = graph.set_index('DL_D')
    graph['DELTA_LOGI'].plot(kind='bar',ax=ax,title=metaLogi[code])

# %%
fig = plt.figure(figsize=(40,40))
cnt=1
for code in Logi['DL_GD_LCLS_CD'].unique():
    ax = fig.add_subplot(5,2,cnt)
    logi_things_plot(delta_logi,code,ax)
    cnt+=1

# %%
len(Logi['DL_GD_LCLS_CD'].unique())
# Out:
# 10

# %% [markdown]
# # 카드데이터 핸들링
# 작년보다 매출이 가장 많이 떨어진 업종을 찾아야한다.
# (20년도 - 19년도) 카드사용량,카드매출양
# (20년도 - 19년도)/(20년도) 카드사용량,카드매출양 비율

# %% [markdown]
# # 카드 차분데이터 생성

# %%
Card_resi = Data['Card'][5] 
Card_fori = Data['Card'][4]
Card_resi['STD_MM'] = Card_resi['STD_DD']%10000
Card_fori['STD_MM'] = Card_fori['STD_DD']%10000

resi19 = Card_resi.loc[Card_resi["STD_DD"]<20200000]
resi20 = Card_resi.loc[Card_resi["STD_DD"]>20200000]

resi19 = resi19.drop(columns="STD_DD").groupby([x for x in resi19.columns if x not in ["USE_CNT","USE_AMT","STD_DD"]]).sum().reset_index()
resi19

resi20 = resi20.drop(columns="STD_DD").groupby([x for x in resi20.columns if x not in ["USE_CNT","USE_AMT","STD_DD"]]).sum().reset_index()
resi20

delta_resi = pd.merge(resi20,resi19,on=[x for x in resi20.columns if x not in ["USE_CNT","USE_AMT","STD_DD"]])
delta_resi.rename({"USE_CNT_x":"USE_CNT_2020","USE_AMT_x":"USE_AMT_2020","USE_CNT_y":"USE_CNT_2019","USE_AMT_y":"USE_AMT_2019"},inplace=True,axis=1)

delta_resi['delta_cnt'] = delta_resi['USE_CNT_2020']-delta_resi['USE_CNT_2019']
delta_resi['delta_amt'] = delta_resi['USE_AMT_2020']-delta_resi['USE_AMT_2019']
delta_resi["SEX_CD"] = delta_resi["SEX_CD"].apply(lambda x: 1 if x=='M' else 0)
delta_resi
# Out:
#         GU_CD  DONG_CD  MCT_CAT_CD  SEX_CD  AGE_CD  STD_MM  USE_CNT_2020  \
# 0         110      517          10       0      20     202             5
# 1         110      517          10       0      20     206            11
# 2         110      517          10       0      20     310             5
# 3         110      517          10       0      20     316             5
# 4         110      517          10       0      20     426             5
# ...       ...      ...         ...     ...     ...     ...           ...
# 986091    350      720          81       1      65     526             5
# 986092    350      720          81       1      65     530             5
# 986093    350      720          81       1      65     531             5
# 986094    350      720          92       1      40     401             5
# 986095    350      720          92       1      45     401             5
#
#         USE_AMT_2020  USE_CNT_2019  USE_AMT_2019  delta_cnt  delta_amt
# 0                316            11           541         -6       -225
# 1                 74             5            81          6         -7
# 2                210             5           162          0         48
# 3                 79            11           162         -6        -83
# 4                267             6           110         -1        157
# ...              ...           ...           ...        ...        ...
# 986091            68             9           192         -4       -124
# 986092            30             4            20          1         10
# 986093            29             9           133         -4       -104
# 986094            92             5            46          0         46
# 986095           400             5           393          0          7
#
# [986096 rows x 12 columns]

# %% [markdown]
# # 업종별 소비 클러스터링

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3,n_init=3)

# %%
cdr20 = Card_resi[Card_resi["STD_DD"]>20200000].groupby(['STD_DD','GU_CD','DONG_CD','MCT_CAT_CD']).sum().reset_index()
cdr19 = Card_resi[Card_resi["STD_DD"]<20200000].groupby(['STD_DD','GU_CD','DONG_CD','MCT_CAT_CD']).sum().reset_index()

cdr20['M'] = cdr20['STD_DD']%10000
cdr19['M'] = cdr19['STD_DD']%10000

cdr_delta = pd.merge(cdr20.drop(columns=['STD_DD','STD_MM','AGE_CD']),cdr19.drop(columns=['STD_DD','STD_MM','AGE_CD']),on=['M','MCT_CAT_CD','GU_CD','DONG_CD'])

cdr_delta["delta_cnt"] = cdr_delta['USE_CNT_x']-cdr_delta['USE_CNT_y']
cdr_delta["delta_amt"] = cdr_delta['USE_AMT_x']-cdr_delta['USE_AMT_y']

cdr_delta.groupby("MCT_CAT_CD").sum()[["delta_amt"]].plot(kind='bar')

cdr_delta.groupby("MCT_CAT_CD").sum()[["delta_cnt"]].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='MCT_CAT_CD'>

# %%
amt_threshold = cdr_delta.groupby("MCT_CAT_CD").sum()[["delta_amt","delta_cnt"]]

amt_threshold
# Out:
#             delta_amt  delta_cnt
# MCT_CAT_CD
# 10          -22109832    -159673
# 20          -21126950    -320567
# 21          -15284799    -423201
# 22           -7843934    -454167
# 30             262685        716
# 31             -31675        213
# 32           -1120067      -1232
# 33          -37924295    -820875
# 34           -1578530     -27734
# 35           -8033814     -32729
# 40         -167373950   -8355587
# 42          -45775106    -819289
# 43            -808103      -5628
# 44           -8936227    -260961
# 50           -8619196    -603159
# 52          -26572494   -3823911
# 60           -1426486        -91
# 62           -6174495    -619125
# 70          -57696323    -121029
# 71          -30858178    -933712
# 80         -200118722   -9149663
# 81            1845401    -338554
# 92             -67840     -26039

# %%
kmeans.fit(amt_threshold)
# Out:
# KMeans(n_clusters=3, n_init=3)

# %%
k_means_mct = dict(zip(amt_threshold.index,kmeans.labels_))

# %%
delta_resi['MCT_CD_CLUSTERed'] = delta_resi['MCT_CAT_CD'].apply(lambda x : k_means_mct[x])

delta_resi.drop([x for x in delta_resi.columns if x[0] == 'U'],axis=1,inplace=True)

# %%
card_loc_des = Data['Card'][1].iloc[1:,1:]
card_loc_des.columns = ["GU_CD","DONG_CD","GU_NM","HDONG_NM"]

card_loc_des['GU_CD'] = card_loc_des['GU_CD'].astype(np.int64)
card_loc_des['DONG_CD'] = card_loc_des['DONG_CD'].astype(np.int64)

delta_resi = pd.merge(delta_resi,card_loc_des,on=['GU_CD','DONG_CD'])

# %%
delta_resi
# Out:
#         GU_CD  DONG_CD  MCT_CAT_CD  SEX_CD  AGE_CD  STD_MM  delta_cnt  \
# 0         110      517          10       0      20     202         -6
# 1         110      517          10       0      20     206          6
# 2         110      517          10       0      20     310          0
# 3         110      517          10       0      20     316         -6
# 4         110      517          10       0      20     426         -1
# ...       ...      ...         ...     ...     ...     ...        ...
# 986091    350      720          81       1      65     526         -4
# 986092    350      720          81       1      65     530          1
# 986093    350      720          81       1      65     531         -4
# 986094    350      720          92       1      40     401          0
# 986095    350      720          92       1      45     401          0
#
#         delta_amt  MCT_CD_CLUSTERed   GU_NM HDONG_NM
# 0            -225                 0   대구 중구      동인동
# 1              -7                 0   대구 중구      동인동
# 2              48                 0   대구 중구      동인동
# 3             -83                 0   대구 중구      동인동
# 4             157                 0   대구 중구      동인동
# ...           ...               ...     ...      ...
# 986091       -124                 2  서울 노원구    상계10동
# 986092         10                 2  서울 노원구    상계10동
# 986093       -104                 2  서울 노원구    상계10동
# 986094         46                 2  서울 노원구    상계10동
# 986095          7                 2  서울 노원구    상계10동
#
# [986096 rows x 11 columns]

# %%
pe = pd.read_csv("../Data/연령별요동인구차분데이터.csv",encoding='cp949')
pe.drop("Unnamed: 0",axis=1,inplace=True)
pe["STD_MM"] = pe['STD_YMD']%10000
pe = pe.iloc[:,3:]

# %%
pe['SEX_CD'] = 1
pe['AGE_CD'] = 1

# %%
new_pe = pd.DataFrame()

for i in pe.columns[1:-4]:
    df = pe[['STD_MM','HDONG_NM','SEX_CD',"AGE_CD","label",i]]
    sex = i[0]
    age = int(i[1:-1])
    if age<20:
        continue
    else:
        if sex == '남':
            sex = 1
        else:
            sex = 0
        age-=4
        df['SEX_CD'] = sex
        df['AGE_CD'] = age
        df.columns = ['STD_MM','HDONG_NM','SEX_CD','AGE_CD',"LABEL","PEOPLE"]
        new_pe = pd.concat([new_pe,df])
# Out:
# <ipython-input-37-e7bd6690e44b>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SEX_CD'] = sex
# <ipython-input-37-e7bd6690e44b>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AGE_CD'] = age

# %%
new_pe['AGE_CD'] = new_pe['AGE_CD'].replace(66,65)

# %%
delta_resi = pd.merge(delta_resi,new_pe,on=['STD_MM','HDONG_NM','SEX_CD','AGE_CD'])

# %%
section = {10: '숙박',
 20: '레저용품',
 21: '레저업소',
 22: '문화취미',
 30: '가구',
 31: '전기',
 32: '주방용구',
 33: '연료판매',
 34: '광학제품',
 35: '가전',
 40: '유통업',
 42: '의복',
 43: '직물',
 44: '신변잡화',
 50: '서적문구',
 52: '사무통신',
 60: '자동차판매',
 62: '자동차정비',
 70: '의료기관',
 71: '보건위생',
 80: '요식업소',
 81: '음료식품',
 92: '수리서비스'}

# %% [markdown]
# # 유통데이터 핸들링

# %%
Data['Delivery'][-1]
# Out:
# ['04_혁신아이디어분야_유통데이터(GS리테일)_데이터정의서 및 문제 데이터.xlsx_stcount_6']

# %%
Data['Delivery'][0]
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0          NaN    테이블 정의서         NaN
# 1          NaN       테이블명         NaN
# 2          NaN      테이블개요         NaN
# 3          NaN       특기사항         NaN
# 4          NaN         순서        컬럼ID
# 5          NaN          1     OPER_DT
# 6          NaN          2         PVN
# 7          NaN          3         BOR
# 8          NaN          4        ADMD
# 9          NaN          5     AMT_IND
# 10         NaN          6  LCLS__10_P
# 11         NaN          7  LCLS__20_P
# 12         NaN          8  LCLS__30_P
# 13         NaN          9  LCLS__40_P
# 14         NaN         10  LCLS__50_P
# 15         NaN         11  LCLS__60_P
# 16         NaN         12  LCLS__70_P
# 17         NaN         13  LCLS__80_P
# 18         NaN         14  LCLS__90_P
#
#                                            Unnamed: 3  Unnamed: 4  \
# 0                                                 NaN         NaN
# 1                              일자별 행정동별 매출지수, 카테고리 비중         NaN
# 2   [적재주기 : 일단위] \n기준년월일의 기준지역 내 점포들의 영업일자별 구매금액을 ...         NaN
# 3   1. 기간 : '19년 2월 1일~'19년 5월 31일, '20년 2월 1일~'20...         NaN
# 4                                                 NaN         컬럼명
# 5                                                 NaN        영업일자
# 6                                                 NaN         시코드
# 7                                                 NaN         구코드
# 8                                                 NaN       행정동코드
# 9                                                 NaN        매출지수
# 10                                                NaN       식사_비중
# 11                                                NaN       간식_비중
# 12                                                NaN     마실거리_비중
# 13                                                NaN     홈&리빙_비중
# 14                                                NaN    헬스&뷰티_비중
# 15                                                NaN  취미&여가활동_비중
# 16                                                NaN     사회활동_비중
# 17                                                NaN    임신/육아_비중
# 18                                                NaN      기호품_비중
#
#      Unnamed: 5           Unnamed: 6
# 0           NaN                  NaN
# 1         테이블ID  TB_DD_STR_PURCH_CLS
# 2           NaN                  NaN
# 3           NaN                  NaN
# 4       물리데이터타입                   비고
# 5    VARCHAR(8)                  NaN
# 6    VARCHAR(5)                  NaN
# 7    VARCHAR(5)                  NaN
# 8    VARCHAR(8)                  NaN
# 9   NUMBER(5,2)                  NaN
# 10  NUMBER(5,2)                 비중_%
# 11  NUMBER(5,2)                 비중_%
# 12  NUMBER(5,2)                 비중_%
# 13  NUMBER(5,2)                 비중_%
# 14  NUMBER(5,2)                 비중_%
# 15  NUMBER(5,2)                 비중_%
# 16  NUMBER(5,2)                 비중_%
# 17  NUMBER(5,2)                 비중_%
# 18  NUMBER(5,2)                 비중_%

# %%
Data['Delivery'][1]
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN        시코드         시명        구코드         구명      행정동코드
# 1          NaN         11      서울특별시       1114         중구   11140520
# 2          NaN         11      서울특별시       1114         중구   11140540
# 3          NaN         11      서울특별시       1114         중구   11140550
# 4          NaN         11      서울특별시       1114         중구   11140570
# ..         ...        ...        ...        ...        ...        ...
# 56         NaN         27      대구광역시       2726        수성구   27260661
# 57         NaN         27      대구광역시       2726        수성구   27260662
# 58         NaN         27      대구광역시       2726        수성구   27260670
# 59         NaN         27      대구광역시       2726        수성구   27260680
# 60         NaN         27      대구광역시       2726        수성구   27260690
#
#    Unnamed: 6
# 0        행정동명
# 1         소공동
# 2         회현동
# 3          명동
# 4          필동
# ..        ...
# 56       범물1동
# 57       범물2동
# 58       고산1동
# 59       고산2동
# 60       고산3동
#
# [61 rows x 7 columns]

# %%
Data['Delivery'][2]
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2           Unnamed: 3
# 0         NaN  분석용상품대분류코드  분석용상품대분류명                상품 예시
# 1         NaN          10         식사   F/F, 김치, 통조림, 즉석식품
# 2         NaN          20         간식  견과, 스낵, 껌/캔디/젤리, 과일
# 3         NaN          30       마실거리              음료, 유제품
# 4         NaN          40       홈&리빙  라이터, 건전지, 일회용품, 방향제
# 5         NaN          50      헬스&뷰티      마스크, 샴푸, 린스, 칫솔
# 6         NaN          60    취미&여가활동   완구, 대형가전, 애완동물, 레져
# 7         NaN          70       사회활동      문구, 소형가전(이어폰 등)
# 8         NaN          80      임신/육아               유아, 인형

# %%
Data['Delivery'][3]
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0         NaN        NaN        NaN           NaN           NaN           NaN
# 1         NaN        NaN        NaN           NaN           NaN           NaN
# 2         PVN        BOR       ADMD  2.019020e+07  2.019020e+07  2.019020e+07
# 3          전체        NaN        NaN  1.198007e+00  1.017985e+00  9.636836e-01
# 4       서울특별시        NaN        NaN  1.188696e+00  1.004386e+00  9.537751e-01
# ..        ...        ...        ...           ...           ...           ...
# 65      대구광역시        수성구       범물1동  7.554043e-01  9.182633e-01  8.201643e-01
# 66      대구광역시        수성구       범물2동  1.049858e+00  8.587615e-01  8.857105e-01
# 67      대구광역시        수성구       고산1동  1.064336e+00  9.400263e-01  9.436377e-01
# 68      대구광역시        수성구       고산2동  1.076418e+00  1.172479e+00  1.153766e+00
# 69      대구광역시        수성구       고산3동  8.560714e-01  8.959117e-01  9.243045e-01
#
#       Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...  Unnamed: 234  \
# 0            NaN           NaN           NaN           NaN  ...           NaN
# 1            NaN           NaN           NaN           NaN  ...           NaN
# 2   2.019020e+07  2.019020e+07  2.019021e+07  2.019021e+07  ...  2.020052e+07
# 3   9.187590e-01  1.028130e+00  9.000219e-01  1.062491e+00  ...  1.080985e+00
# 4   8.995791e-01  1.036262e+00  8.927647e-01  1.079589e+00  ...  1.162798e+00
# ..           ...           ...           ...           ...  ...           ...
# 65  1.043473e+00  1.065493e+00  8.364034e-01  8.346464e-01  ...  8.606028e-01
# 66  9.766516e-01  1.270511e+00  8.135788e-01  8.163705e-01  ...  8.770364e-01
# 67  9.545527e-01  9.897848e-01  8.474912e-01  8.759402e-01  ...  7.901645e-01
# 68  1.556855e+00  1.658221e+00  1.122046e+00  1.105032e+00  ...  1.078168e+00
# 69  9.014647e-01  9.846605e-01  8.037005e-01  8.843768e-01  ...  7.296444e-01
#
#     Unnamed: 235  Unnamed: 236  Unnamed: 237  Unnamed: 238  Unnamed: 239  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2   2.020052e+07  2.020052e+07  2.020052e+07  2.020053e+07  2.020053e+07
# 3   1.020417e+00  8.858034e-01  1.021254e+00  1.067526e+00  1.063149e+00
# 4   1.078928e+00  9.301470e-01  1.098651e+00  1.143194e+00  1.147769e+00
# ..           ...           ...           ...           ...           ...
# 65  9.154997e-01  8.292520e-01  8.418950e-01  9.494111e-01  8.974344e-01
# 66  7.662027e-01  6.668240e-01  7.512638e-01  7.546354e-01  7.568331e-01
# 67  7.786123e-01  6.651004e-01  7.030475e-01  7.805854e-01  7.452863e-01
# 68  1.093085e+00  1.139640e+00  1.183757e+00  1.077460e+00  1.189024e+00
# 69  6.924392e-01  5.819835e-01  6.290875e-01  6.992688e-01  6.534391e-01
#
#     Unnamed: 240  Unnamed: 241  Unnamed: 242  Unnamed: 243
# 0            NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN
# 2   2.020053e+07  2.020053e+07  2.020053e+07  2.020053e+07
# 3   1.076086e+00  1.137684e+00  1.045754e+00  9.287247e-01
# 4   1.169708e+00  1.226083e+00  1.110484e+00  9.781009e-01
# ..           ...           ...           ...           ...
# 65  8.507764e-01  9.648802e-01  9.633305e-01  7.999963e-01
# 66  7.066945e-01  7.230945e-01  8.189332e-01  7.958159e-01
# 67  7.331229e-01  8.213566e-01  8.628027e-01  7.323572e-01
# 68  1.180665e+00  1.133741e+00  1.152602e+00  1.094919e+00
# 69  7.005690e-01  7.544518e-01  7.882606e-01  5.673675e-01
#
# [70 rows x 244 columns]

# %%
val = list(Data['Delivery'][2]['Unnamed: 2'].values)[1:]

# %%
Deli = Data['Delivery'][5]

# %%
Deli['STD_DM'] = Deli['OPER_DT']//100

# %%
Deli_month = Deli.groupby('STD_DM').mean()

# %%
fig = plt.figure(figsize=(20,20))
fig.suptitle("2019년 월별 지수 그래프",fontsize=20)
cnt = 1
for i in range(4):
    fig.add_subplot(2,2,cnt)
    plt.pie(Deli_month.iloc[:4,2:].iloc[i],labels=val)
    cnt+=1
# Out:
# <ipython-input-50-ac2b0e8ed2a2>:6: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(Deli_month.iloc[:4,2:].iloc[i],labels=val)

# %%
fig = plt.figure(figsize=(20,20))
fig.suptitle("2020년 월별 지수 그래프",fontsize=20)
cnt = 1
for i in range(4):
    fig.add_subplot(2,2,cnt)
    plt.pie(Deli_month.iloc[4:,2:].iloc[i],labels=val)
    cnt+=1

# %%
(Deli_month.iloc[4:,2:].reset_index() - Deli_month.iloc[:4,2:].reset_index()).drop('STD_DM',axis=1).plot(kind = 'bar',rot=0,figsize=(10,10))
plt.legend(val,bbox_to_anchor=(1,1))
plt.xticks([0,1,2,3],['2월','3월','4월','5월'])
# Out:
# ([<matplotlib.axis.XTick at 0x1c605303eb0>,
#   <matplotlib.axis.XTick at 0x1c605303e80>,
#   <matplotlib.axis.XTick at 0x1c60536f6d0>,
#   <matplotlib.axis.XTick at 0x1c6053931f0>],
#  [Text(0, 0, '2월'), Text(1, 0, '3월'), Text(2, 0, '4월'), Text(3, 0, '5월')])

# %%
Data['Delivery'][2]
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2           Unnamed: 3
# 0         NaN  분석용상품대분류코드  분석용상품대분류명                상품 예시
# 1         NaN          10         식사   F/F, 김치, 통조림, 즉석식품
# 2         NaN          20         간식  견과, 스낵, 껌/캔디/젤리, 과일
# 3         NaN          30       마실거리              음료, 유제품
# 4         NaN          40       홈&리빙  라이터, 건전지, 일회용품, 방향제
# 5         NaN          50      헬스&뷰티      마스크, 샴푸, 린스, 칫솔
# 6         NaN          60    취미&여가활동   완구, 대형가전, 애완동물, 레져
# 7         NaN          70       사회활동      문구, 소형가전(이어폰 등)
# 8         NaN          80      임신/육아               유아, 인형

# %%
Deli_month["ETC"] = Deli_month[['LCLS_40_P','LCLS_60_P','LCLS_70_P','LCLS_80_P']].sum(axis=1)

# %%
Deli_month['EAT'] = Deli_month[['LCLS_10_P','LCLS_20_P','LCLS_30_P']].sum(axis=1)

# %%
Deli_month['MASK'] = Deli_month['LCLS_50_P']

# %%
(Deli_month[['EAT',"ETC","MASK"]][4:].reset_index() - Deli_month[['EAT',"ETC","MASK"]][:4].reset_index()).drop('STD_DM',axis=1).plot(rot=0,figsize=(10,10))
plt.legend(['EAT',"ETC","MASK"],bbox_to_anchor=(1,1))
plt.xticks([-1,0,1,2,3,4],["",'2월','3월','4월','5월',""])
# Out:
# ([<matplotlib.axis.XTick at 0x1c6053dd580>,
#   <matplotlib.axis.XTick at 0x1c6053dd550>,
#   <matplotlib.axis.XTick at 0x1c6053f7a30>,
#   <matplotlib.axis.XTick at 0x1c60540beb0>,
#   <matplotlib.axis.XTick at 0x1c605415400>,
#   <matplotlib.axis.XTick at 0x1c605415910>],
#  [Text(-1, 0, ''),
#   Text(0, 0, '2월'),
#   Text(1, 0, '3월'),
#   Text(2, 0, '4월'),
#   Text(3, 0, '5월'),
#   Text(4, 0, '')])

# %% [markdown]
# # 코로나 데이터 핸들링

# %%
Data['Corona'][0]
# Out:
#          date  confirmed  death  released   tested  negative
# 0    20200121          1      0         0        1         0
# 1    20200122          1      0         0        1         0
# 2    20200123          1      0         0        1         0
# 3    20200124          2      0         0        2         0
# 4    20200125          2      0         0        2         0
# ..        ...        ...    ...       ...      ...       ...
# 217  20200825      17945    310     14286  1825837   1757530
# 218  20200826      18265    312     14368  1849506   1778446
# 219  20200827      18706    313     14461  1869579   1798832
# 220  20200828      19077    316     14551  1887717   1817929
# 221  20200829      19400    321     14765  1909329   1835883
#
# [222 rows x 6 columns]

# %%
Corona = Data['Corona'][0]

# %%
Corona_1 = Corona[:]

# %%
Corona_1
# Out:
#          date  confirmed  death  released   tested  negative
# 0    20200121          1      0         0        1         0
# 1    20200122          1      0         0        1         0
# 2    20200123          1      0         0        1         0
# 3    20200124          2      0         0        2         0
# 4    20200125          2      0         0        2         0
# ..        ...        ...    ...       ...      ...       ...
# 217  20200825      17945    310     14286  1825837   1757530
# 218  20200826      18265    312     14368  1849506   1778446
# 219  20200827      18706    313     14461  1869579   1798832
# 220  20200828      19077    316     14551  1887717   1817929
# 221  20200829      19400    321     14765  1909329   1835883
#
# [222 rows x 6 columns]

# %%
Corona_1.index+=1

# %%
Corona['day_confirmed'] =Corona['confirmed']-Corona_1['confirmed']

# %%
Corona['STD_MM'] = Corona['date']%10000

# %%
Corona = Corona.loc[Corona['STD_MM']>200][['STD_MM','day_confirmed']]

# %% [markdown]
# # 데이터 피쳐 정의부

# %%
feature_table = pd.DataFrame()

# %%
delta_resi = pd.merge(delta_resi,Corona,on='STD_MM')

# %%
feature_table = (delta_resi.drop(columns=['MCT_CAT_CD','GU_NM','HDONG_NM','MCT_CD_CLUSTERed']))

# %%
feature_table['double_amt'] = feature_table['delta_amt'].apply(lambda x:x**2)
feature_table['double_cnt'] = feature_table['delta_cnt'].apply(lambda x:x**2)

# %%
feature_table.drop(columns = ['LABEL'],inplace=True)

# %%
 X,y = feature_table,delta_resi.drop(columns='MCT_CAT_CD')['MCT_CD_CLUSTERed']

# %% [markdown]
# 피해군을 1차 분류를 해준뒤 학습시켜 차분값에 따른 차등을 예측하고 그 예측값을 통해 나온 값을 다시 사용하여 인사이트를 얻는다

# %% [markdown]
# # 모델 테스트

# %% [markdown]
# # Tree Based Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=200)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier(n_estimators=100,random_state=42,n_jobs=-1,max_depth=25,oob_score=True).fit(X_train,y_train)
print("RandomForest")
print("훈련 세트 정확도: {:.3f}".format(RF.score(X_train,y_train)))
print("테스트 세트 정확도: {:.3f}".format(RF.score(X_test,y_test)))
# Out:
# RandomForest
# 훈련 세트 정확도: 0.987
# 테스트 세트 정확도: 0.681

# %%
plt.barh(feature_table.columns,RF.feature_importances_)
# Out:
# <BarContainer object of 11 artists>

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ADA = AdaBoostClassifier(n_estimators=20, random_state = 42).fit(X_train,y_train)
print("AdaBoost")
print("훈련 세트 정확도: {:.3f}".format(ADA.score(X_train,y_train)))
print("테스트 세트 정확도: {:.3f}".format(ADA.score(X_test,y_test)))
# Out:
# AdaBoost
# 훈련 세트 정확도: 0.524
# 테스트 세트 정확도: 0.523

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbrt = GradientBoostingClassifier(n_estimators=20, random_state = 42).fit(X_train,y_train)
print("GradientBoosting")
print("훈련 세트 정확도: {:.3f}".format(gbrt.score(X_train,y_train)))
print("테스트 세트 정확도: {:.3f}".format(gbrt.score(X_test,y_test)))
# Out:
# GradientBoosting
# 훈련 세트 정확도: 0.542
# 테스트 세트 정확도: 0.540

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
xtree = ExtraTreesClassifier(n_estimators = 5, n_jobs=-1, random_state=0)
xtree.fit(X_train,y_train)
print("ExtraTreesClassifier")
print("훈련 세트 정확도: {:.3f}".format(xtree.score(X_train,y_train)))
print("테스트 세트 정확도: {:.3f}".format(xtree.score(X_test,y_test)))
# Out:
# ExtraTreesClassifier
# 훈련 세트 정확도: 1.000
# 테스트 세트 정확도: 0.608

# %% [markdown]
# # Required to scale Data set

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train
# Out:
#          GU_CD  DONG_CD  SEX_CD  AGE_CD  STD_MM  delta_cnt  delta_amt  \
# 731200     350      700       0      55     321          0        -23
# 314777     140      520       0      30     318        -18       -481
# 1067807    350      600       0      25     421        -13        -70
# 438853     110      595       1      65     516        103       6785
# 706428     140      635       0      20     214         -5       -671
# ...        ...      ...     ...     ...     ...        ...        ...
# 863311     350      630       1      35     423         -4       -136
# 369484     140      665       1      25     420         65        361
# 781098     350      595       1      35     228          0       1546
# 522052     110      595       0      45     222        -60      -2215
# 12905      260      610       1      20     206        -12       -143
#
#           PEOPLE  day_confirmed  double_amt  double_cnt
# 731200    -80.79          147.0         529           0
# 314777  -4252.50           93.0      231361         324
# 1067807  -569.76            9.0        4900         169
# 438853   -155.89           19.0    46036225       10609
# 706428    304.30            0.0      450241          25
# ...          ...            ...         ...         ...
# 863311   -626.14            8.0       18496          16
# 369484   -286.78           13.0      130321        4225
# 781098  -2504.28          571.0     2390116           0
# 522052  -2270.17          229.0     4906225        3600
# 12905     -82.12            3.0       20449         144
#
# [855814 rows x 11 columns]

# %%
X_train
# Out:
#          GU_CD  DONG_CD  SEX_CD  AGE_CD  STD_MM  delta_cnt  delta_amt  \
# 731200     350      700       0      55     321          0        -23
# 314777     140      520       0      30     318        -18       -481
# 1067807    350      600       0      25     421        -13        -70
# 438853     110      595       1      65     516        103       6785
# 706428     140      635       0      20     214         -5       -671
# ...        ...      ...     ...     ...     ...        ...        ...
# 863311     350      630       1      35     423         -4       -136
# 369484     140      665       1      25     420         65        361
# 781098     350      595       1      35     228          0       1546
# 522052     110      595       0      45     222        -60      -2215
# 12905      260      610       1      20     206        -12       -143
#
#           PEOPLE  day_confirmed  double_amt  double_cnt
# 731200    -80.79          147.0         529           0
# 314777  -4252.50           93.0      231361         324
# 1067807  -569.76            9.0        4900         169
# 438853   -155.89           19.0    46036225       10609
# 706428    304.30            0.0      450241          25
# ...          ...            ...         ...         ...
# 863311   -626.14            8.0       18496          16
# 369484   -286.78           13.0      130321        4225
# 781098  -2504.28          571.0     2390116           0
# 522052  -2270.17          229.0     4906225        3600
# 12905     -82.12            3.0       20449         144
#
# [855814 rows x 11 columns]

# %%
from sklearn.neural_network import MLPClassifier

# %%
MLP = MLPClassifier()
